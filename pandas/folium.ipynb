# %%
import numpy as np
import pandas as pd
import platform
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import folium


m = folium.Map(location = [37.572656, 126.973304], zoom_start = 15)

# Marker 출력
folium.Marker(location=[36.572656, 126.973304], popup="KB카드", icon=folium.Icon(icon='cloud')).add_to(m)
folium.Marker(location=[36.569027, 126.987029], popup="Mega IT", icon=folium.Icon(icon='cloud')).add_to(m)

folium.RegularPolygonMarker(location=[37.569027, 126.987029], popup="PolygonMarker",number_of_sides=5, rotation=0, radius=60, fill = True, fill_color="#999999").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df = pd.read_excel('./data/서울지역_대학교_위치.xlsx')
map = folium.Map(location = [37.55, 126.98], zoom_start = 12)

for name, lat, lon in zip(df['Unnamed: 0'], df['위도'], df['경도']):
    folium.CircleMarker([lat, lon],popup=name, radius=30, color='blue', fill=True, fill_color='coral', fill_opacity=0.7).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 경기도 인구 단계 구분도
# json 파싱을 위한 패키지
import json

# 경기도 입구 데이터 가져오기
df = pd.read_excel('./data/경기도인구데이터.xlsx')
print(df.head())
# Out:
#        구분    2007    2008    2009    2010    2011    2012    2013    2014  \
# 0  수원시장안구  287474  285803  290798  293692  290999  291757  300908  301196
# 1  수원시권선구  310553  308177  304097  306783  321176  332633  331773  339835
# 2  수원시팔달구  216945  213235  219833  216503  209772  206794  204805  203479
# 3  수원시영통구  252730  260210  258421  260557  266542  289074  310671  329718
# 4  성남시수정구  256744  248452  242161  241070  236123  233997  228167  223539
#
#      2015    2016    2017
# 0  299016  296479  293828
# 1  351053  358393  365653
# 2  199180  198515  193311
# 3  335375  340654  349836
# 4  219531  232841  236932

# %%
# 컬럼의 이름이 숫자 형태라서 사여하기가 번거러울 수 있으므로 문자열로 변환
df.column = df.columns.map(str)
# Out:
# /var/folders/8y/qly304_55c1cf35dff76v_lh0000gn/T/ipykernel_5530/2252063603.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.column = df.columns.map(str)

# %%
 geo_data = json.load(open('./data/경기도행정구역겅계.json', encoding='utf-8-'))
래ㅣㅕㅕ
print(geo_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 geo_data = json.load(open('./data/경기도행정구역겅계.json'))
#       2 래ㅣㅕㅕ
#       3 print(geo_data)
#
# File /opt/homebrew/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/경기도행정구역겅계.json'

# %%
g_map = folumnNap(incrtion][38, 331,123,0; zoo__start=0
# dollium Chorpleth(geo_s01

follumChropleth(geo_data = geo_data, data=df["2007']
                columns=[df.index, df['2007']
                fill_color = ;LQrRddd, fill_cpacity 0.8 lineopacity=0.3
                
trthreahold(scale=[10000,30000,50000 7000_
        

tree Chroplace
# Out:
#   Cell In[16], line 1
#     g_map = folumnNap(incrtion][38, 331,123,0; zoo__start=0
#                               ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
