# %%
import numpy as np
import pandas as pd

# %%
items = {
    'code' : [1, 2, 3],
    'name' : ['apple', 'fruit', 'grape'],
    'price' : [3000, 23000, 3700]
}
df = pd.DataFrame(items)
print(df)
# Out:
#    code   name  price
# 0     1  apple   3000
# 1     2  fruit  23000
# 2     3  grape   3700

# %%
df.to_csv('./data/pddata.csv')

# %%
# writer = pd.ExcelWriter('./data/excelwriter.xlsx')
# df.to_excel(writer)
# writer.save()

# %%
# li = pd.read_html('https://ko.wikipedia.org/wiki/프로젝트_주피터')
# print(li)

# %%
import urllib.request

response = urllib.request.urlopen("https://www.kakao.com")

data =response.read()

print(data)

encoding = response.info().get_content_charset()
html = data.decode(encoding)
print(html)
# Out:
# b'<!doctype html><html data-n-head-ssr lang="ko" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22ko%22%7D%7D"><head ><title>\xec\xb9\xb4\xec\xb9\xb4\xec\x98\xa4</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="user-scalable=no, width=device-width, height=device-height, initial-scale=1, maximum-scale=1, minimum-scale=1.0, viewport-fit=cover"><meta data-n-head="ssr" property="og:type" content="website"><meta data-n-head="ssr" property="og:site_name" content="kakaocorp.com"><meta data-n-head="ssr" data-hid="url" property="og:url" content="//www.kakaocorp.com/page"><meta data-n-head="ssr" data-hid="title" property="og:title" content="Kakao"><meta data-n-head="ssr" data-hid="image" property="og:image" content="//t1.kakaocdn.net/kakaocorp/corp_thumbnail/Kakao.png"><meta data-n-head="ssr" data-hid="twitter" name="twitter:image" content="//t1.kakaocdn.net/kakaocorp/corp_thumbnail/Kakao.png"><meta data-n-head="ssr" name="naver-site-verification" conte
# ...

# %%
import urllib.request
from urllib.parse import quote

# %%
# keyword = quote("사이버가수아담")

# response = urllib.request.urlopen('https://search.hani.co.kr/search?command=query&media=common&searchword=사이버가수아담&x=0&y=0&_ga=2.201072038.94576732.1691544905-1687975594.1691544905')
# data = response.read()
# print(data)

# encoding = response.info().get_content.charset()
# html = data.decode(encoding)
# print(html)

# %%
import requests

#GET 방식 요청
response = requests.get('http://httpbin.org/get')
print(response.text)

# %%
import requests, bs4

# %%
# 전송할 파라미터
dic = {"id":"itstudy", "name":"현기홍", "alias":"A"}

# url이 잘못되었거나 네트어크 연결이 안되면 예외
try:
    response = requests.get('http://finance.daum.net')
    print(response.text)

    # 파싱 가능한지 확인 - 파싱이 불가능하면 예외
    bs = bs4.BeautifulSoup(response.text, 'html.parser')

except Exception as e:
    print('예외 발생: ', e)

else:
    print(bs.body.span.get_text())

# %%
try:
    response = requests.get('http://tv.naver.com/r/category/drama')
    html = response.text
    # print(html)

    bs = bs4.BeautifulSoup(html, 'html.parser')
    # print(bs)

    #선택자에 해당하는 부분만 가져오기
    tags = bs.select('#content > div > div > div > div:nth-child(1) > div > dl > dt > a')

    for tag in tags:
        print(tag.getText())

except Exception as e:
    print('예외 발생: ', e)
